# %% [markdown]
# time to communte high
# income low
# children population high
# geo child care centre (no)

# %% [markdown]
# a new Fee Subsidy child care centre

# %%
grocery store target income above median

# %% [markdown]
# ## Data

# %% [markdown]
# 1. Neigborhood Crime Rates from Toronto Polic Service
# https://data.torontopolice.on.ca/datasets/neighbourhood-crime-rates-boundary-file-
#
# 2. Neighborhood Profiles from City of Toronto's Open Data Portal
# https://open.toronto.ca/dataset/neighbourhood-profiles/
#
# 3. Foursquare API

# %%
import pandas as pd

# %% [markdown]
# ### Finding crime rates in each neighborhood in 2014-2019 (Include only Break and Enter, Robbery, Theft Over)

# %%
import pandas as pd

# %%
crime_rates_df=pd.read_csv("crime_rates.csv")
crime_rates_df
# Out:
#      OBJECTID            Neighbourhood  Hood_ID  Population  Assault_2014  \
# 0           1           Yonge-St.Clair       97       12528            20
# 1           2  York University Heights       27       27593           271
# 2           3         Lansing-Westgate       38       16164            44
# 3           4       Yorkdale-Glen Park       31       14804           106
# 4           5      Stonegate-Queensway       16       25051            88
# ..        ...                      ...      ...         ...           ...
# 135       136                 Milliken      130       26572            66
# 136       137            Pleasant View       46       15818            34
# 137       138                 Wychwood       94       14349            54
# 138       139       Leaside-Bennington       56       16828            38
# 139       140     Briar Hill-Belgravia      108       14257            65
#
#      Assault_2015  Assault_2016  Assault_2017  Assault_2018  Assault_2019  \
# ...

# %%
crime_rates_df2 = crime_rates_df[["Neighbourhood","Population", "BreakandEnter_AVG", "Robbery_AVG", "TheftOver_AVG"]]
crime_rates_df2
# Out:
#                Neighbourhood  Population  BreakandEnter_AVG  Robbery_AVG  \
# 0             Yonge-St.Clair       12528               23.3          5.7
# 1    York University Heights       27593              113.2         75.8
# 2           Lansing-Westgate       16164               38.8         14.7
# 3         Yorkdale-Glen Park       14804               63.3         31.5
# 4        Stonegate-Queensway       25051               52.8         20.7
# ..                       ...         ...                ...          ...
# 135                 Milliken       26572              108.3         32.7
# 136            Pleasant View       15818               19.8         11.8
# 137                 Wychwood       14349               34.0         13.8
# 138       Leaside-Bennington       16828               33.3          7.5
# 139     Briar Hill-Belgravia       14257               36.7         21.5
#
#      TheftOver_AVG
# 0              4.3
# 1             36.3
# 2              7.0
# ...

# %%
crime_rates_df2["Total crime rate"] = crime_rates_df2.iloc[:, 2:5].sum(axis=1)
crime_rates_df2["Total crime rate per capita"] = crime_rates_df2["Total crime rate"] / crime_rates_df2["Population"]
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
crime_rates_df2
# Out:
#                Neighbourhood  Population  BreakandEnter_AVG  Robbery_AVG  \
# 0             Yonge-St.Clair       12528               23.3          5.7
# 1    York University Heights       27593              113.2         75.8
# 2           Lansing-Westgate       16164               38.8         14.7
# 3         Yorkdale-Glen Park       14804               63.3         31.5
# 4        Stonegate-Queensway       25051               52.8         20.7
# ..                       ...         ...                ...          ...
# 135                 Milliken       26572              108.3         32.7
# 136            Pleasant View       15818               19.8         11.8
# 137                 Wychwood       14349               34.0         13.8
# 138       Leaside-Bennington       16828               33.3          7.5
# 139     Briar Hill-Belgravia       14257               36.7         21.5
#
#      TheftOver_AVG  Total crime rate  Total crime rate per capita
# ...

# %% [markdown]
# ### Finding percentage of household income over 60k in each neighborhood

# %%
neigh_profile=pd.read_csv("neighborhood_profiles_2016b.csv")
neigh_profile
# Out:
#        _id                   Category  \
# 0        1  Neighbourhood Information
# 1        2  Neighbourhood Information
# 2        3                 Population
# 3        4                 Population
# 4        5                 Population
# ...    ...                        ...
# 2378  2379                   Mobility
# 2379  2380                   Mobility
# 2380  2381                   Mobility
# 2381  2382                   Mobility
# 2382  2383                   Mobility
#
#                                                  Topic  \
# 0                            Neighbourhood Information
# 1                            Neighbourhood Information
# 2                             Population and dwellings
# 3                             Population and dwellings
# 4                             Population and dwellings
# ...                                                ...
# 2378  Mobility status - Place of residence 5 years ago
# ...

# %%
household_df=neigh_profile.iloc[1054:1071, 4:]
household_df
# Out:
#                                          Characteristic City of Toronto  \
# 1054  Total - Household after-tax income groups in 2...       1,112,930
# 1055                                       Under $5,000          34,795
# 1056                                   $5,000 to $9,999          23,615
# 1057                                 $10,000 to $14,999          37,080
# 1058                                 $15,000 to $19,999          55,930
# 1059                                 $20,000 to $24,999          51,910
# 1060                                 $25,000 to $29,999          52,205
# 1061                                 $30,000 to $34,999          53,515
# 1062                                 $35,000 to $39,999          55,545
# 1063                                 $40,000 to $44,999          55,770
# 1064                                 $45,000 to $49,999          53,385
# 1065                                 $50,000 to $59,999          98,910
# ...

# %%
household_df2 = household_df.transpose()
household_df2
# Out:
#                                                                            1054  \
# Characteristic                Total - Household after-tax income groups in 2...
# City of Toronto                                                       1,112,930
# Agincourt North                                                           9,115
# Agincourt South-Malvern West                                              8,140
# Alderwood                                                                 4,620
# ...                                                                         ...
# Wychwood                                                                  5,880
# Yonge-Eglinton                                                            5,680
# Yonge-St.Clair                                                            7,010
# York University Heights                                                  10,165
# Yorkdale-Glen Park                                                        5,345
#
# ...

# %%
household_df3=household_df2.drop(household_df2.columns[1:12],axis=1)
household_df3
# Out:
#                                                                            1054  \
# Characteristic                Total - Household after-tax income groups in 2...
# City of Toronto                                                       1,112,930
# Agincourt North                                                           9,115
# Agincourt South-Malvern West                                              8,140
# Alderwood                                                                 4,620
# ...                                                                         ...
# Wychwood                                                                  5,880
# Yonge-Eglinton                                                            5,680
# Yonge-St.Clair                                                            7,010
# York University Heights                                                  10,165
# Yorkdale-Glen Park                                                        5,345
#
# ...

# %%
household_df3.columns = ['total', '60000-69999','70000-79999','80000-89999','90000-99999','over 100000']

# %%
household_df4 = household_df3.drop('Characteristic')
household_df4
# Out:
#                                   total 60000-69999 70000-79999 80000-89999  \
# City of Toronto               1,112,930      86,755      75,120      63,360
# Agincourt North                   9,115         755         695         640
# Agincourt South-Malvern West      8,140         755         630         500
# Alderwood                         4,620         355         365         310
# Annex                            15,940       1,060         820         750
# ...                                 ...         ...         ...         ...
# Wychwood                          5,880         400         380         305
# Yonge-Eglinton                    5,680         415         345         255
# Yonge-St.Clair                    7,010         475         450         335
# York University Heights          10,165         870         715         575
# Yorkdale-Glen Park                5,345         445         365         290
#
#                              90000-99999 over 100000
# ...

# %%
def convert_comma(val):
    """
    Convert the string number value to a float
     - Remove commas
     - Convert to float type
    """
    new_val = val.replace(',','')
    return float(new_val)

# %%
household_df4["total"] = household_df4["total"].apply(convert_comma)
household_df4["60000-69999"] = household_df4["60000-69999"].apply(convert_comma)
household_df4["70000-79999"] = household_df4["70000-79999"].apply(convert_comma)
household_df4["80000-89999"] = household_df4["80000-89999"].apply(convert_comma)
household_df4["90000-99999"] = household_df4["90000-99999"].apply(convert_comma)
household_df4["over 100000"] = household_df4["over 100000"].apply(convert_comma)
household_df4
# Out:
#                                   total  60000-69999  70000-79999  \
# City of Toronto               1112930.0      86755.0      75120.0
# Agincourt North                  9115.0        755.0        695.0
# Agincourt South-Malvern West     8140.0        755.0        630.0
# Alderwood                        4620.0        355.0        365.0
# Annex                           15940.0       1060.0        820.0
# ...                                 ...          ...          ...
# Wychwood                         5880.0        400.0        380.0
# Yonge-Eglinton                   5680.0        415.0        345.0
# Yonge-St.Clair                   7010.0        475.0        450.0
# York University Heights         10165.0        870.0        715.0
# Yorkdale-Glen Park               5345.0        445.0        365.0
#
#                               80000-89999  90000-99999  over 100000
# City of Toronto                   63360.0      51570.0     263465.0
# ...

# %%
household_df4['Total over 60k']=household_df4.iloc[:, 1:6].sum(axis=1)
household_df4
# Out:
#                                   total  60000-69999  70000-79999  \
# City of Toronto               1112930.0      86755.0      75120.0
# Agincourt North                  9115.0        755.0        695.0
# Agincourt South-Malvern West     8140.0        755.0        630.0
# Alderwood                        4620.0        355.0        365.0
# Annex                           15940.0       1060.0        820.0
# ...                                 ...          ...          ...
# Wychwood                         5880.0        400.0        380.0
# Yonge-Eglinton                   5680.0        415.0        345.0
# Yonge-St.Clair                   7010.0        475.0        450.0
# York University Heights         10165.0        870.0        715.0
# Yorkdale-Glen Park               5345.0        445.0        365.0
#
#                               80000-89999  90000-99999  over 100000  \
# City of Toronto                   63360.0      51570.0     263465.0
# ...

# %%
household_df4['Percentage over 60k']=household_df4['Total over 60k']/household_df4['total']
household_df4
# Out:
#                                   total  60000-69999  70000-79999  \
# City of Toronto               1112930.0      86755.0      75120.0
# Agincourt North                  9115.0        755.0        695.0
# Agincourt South-Malvern West     8140.0        755.0        630.0
# Alderwood                        4620.0        355.0        365.0
# Annex                           15940.0       1060.0        820.0
# ...                                 ...          ...          ...
# Wychwood                         5880.0        400.0        380.0
# Yonge-Eglinton                   5680.0        415.0        345.0
# Yonge-St.Clair                   7010.0        475.0        450.0
# York University Heights         10165.0        870.0        715.0
# Yorkdale-Glen Park               5345.0        445.0        365.0
#
#                               80000-89999  90000-99999  over 100000  \
# City of Toronto                   63360.0      51570.0     263465.0
# ...

# %% [markdown]
# Toronto percentage over 60k = 0.485448

# %%
household_df5 = household_df4.drop('City of Toronto')
household_df5
# Out:
#                                 total  60000-69999  70000-79999  80000-89999  \
# Agincourt North                9115.0        755.0        695.0        640.0
# Agincourt South-Malvern West   8140.0        755.0        630.0        500.0
# Alderwood                      4620.0        355.0        365.0        310.0
# Annex                         15940.0       1060.0        820.0        750.0
# Banbury-Don Mills             12125.0       1000.0        790.0        690.0
# ...                               ...          ...          ...          ...
# Wychwood                       5880.0        400.0        380.0        305.0
# Yonge-Eglinton                 5680.0        415.0        345.0        255.0
# Yonge-St.Clair                 7010.0        475.0        450.0        335.0
# York University Heights       10165.0        870.0        715.0        575.0
# Yorkdale-Glen Park             5345.0        445.0        365.0        290.0
#
# ...

# %%
household_df5.index.name='Neighbourhood'
household_df5
# Out:
#                                 total  60000-69999  70000-79999  80000-89999  \
# Neighbourhood
# Agincourt North                9115.0        755.0        695.0        640.0
# Agincourt South-Malvern West   8140.0        755.0        630.0        500.0
# Alderwood                      4620.0        355.0        365.0        310.0
# Annex                         15940.0       1060.0        820.0        750.0
# Banbury-Don Mills             12125.0       1000.0        790.0        690.0
# ...                               ...          ...          ...          ...
# Wychwood                       5880.0        400.0        380.0        305.0
# Yonge-Eglinton                 5680.0        415.0        345.0        255.0
# Yonge-St.Clair                 7010.0        475.0        450.0        335.0
# York University Heights       10165.0        870.0        715.0        575.0
# Yorkdale-Glen Park             5345.0        445.0        365.0        290.0
#
# ...

# %%
df_merged=pd.merge(household_df5,crime_rates_df2, on="Neighbourhood")

# %%
df_merged
# Out:
#                     Neighbourhood    total  60000-69999  70000-79999  \
# 0                 Agincourt North   9115.0        755.0        695.0
# 1    Agincourt South-Malvern West   8140.0        755.0        630.0
# 2                       Alderwood   4620.0        355.0        365.0
# 3                           Annex  15940.0       1060.0        820.0
# 4               Banbury-Don Mills  12125.0       1000.0        790.0
# ..                            ...      ...          ...          ...
# 135                      Wychwood   5880.0        400.0        380.0
# 136                Yonge-Eglinton   5680.0        415.0        345.0
# 137                Yonge-St.Clair   7010.0        475.0        450.0
# 138       York University Heights  10165.0        870.0        715.0
# 139            Yorkdale-Glen Park   5345.0        445.0        365.0
#
#      80000-89999  90000-99999  over 100000  Total over 60k  \
# 0          640.0        500.0       1920.0          4510.0
# ...

# %%
df_merged2=df_merged.drop(columns=['total', '60000-69999', '70000-79999', '80000-89999', '90000-99999','over 100000', 'Total over 60k', 'BreakandEnter_AVG', 'Robbery_AVG', 'TheftOver_AVG'])

# %%
df_merged2.head()
# Out:
#                   Neighbourhood  Percentage over 60k  Population  \
# 0               Agincourt North             0.494789       29113
# 1  Agincourt South-Malvern West             0.465602       23757
# 2                     Alderwood             0.609307       12054
# 3                         Annex             0.502196       30526
# 4             Banbury-Don Mills             0.550515       27695
#
#    Total crime rate  Total crime rate per capita
# 0              88.4                     0.003036
# 1             120.4                     0.005068
# 2              38.3                     0.003177
# 3             217.8                     0.007135
# 4              98.5                     0.003557

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/conda/envs/python/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-49-e8814b6683d5> in <module>
# ----> 1 df_merged2[1]
#
# ...

# %%
CLIENT_ID = 'I34N2FUJWRUUAQOI5PPZ5B2ROPLBWLGLUFK3JIKKQOD3RA4F' 
CLIENT_SECRET = 'V2KV1BMXEFIDV2JMFJTKZKGNTVWGWOZGT0I5KK4RHPPCOUXE' 
VERSION = '20180605'

# %%
df_merged2['Neighbourhood']
# Out:
# 0                   Agincourt North
# 1      Agincourt South-Malvern West
# 2                         Alderwood
# 3                             Annex
# 4                 Banbury-Don Mills
#                    ...
# 135                        Wychwood
# 136                  Yonge-Eglinton
# 137                  Yonge-St.Clair
# 138         York University Heights
# 139              Yorkdale-Glen Park
# Name: Neighbourhood, Length: 140, dtype: object

# %%
# Out:
# (13, 18)

# %%
# !pip install geopy
from geopy.geocoders import Nominatim
# Out:
# ...
#      |████████████████████████████████| 122kB 5.9MB/s eta 0:00:01
# ...

# %%
address = 'Wychwood, Toronto, ON, Canada'

geolocator = Nominatim(user_agent="vic_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
melbourne_city_centre = (latitude, longitude)
print('The geographical coordinates of Agincourt North are {}, {}.'.format(latitude, longitude))
# Out:
# The geographical coordinates of Agincourt North are 43.682121699999996, -79.42383883756801.

# %%
latitude_list = []
longitude_list = []
for i in df_merged2['Neighbourhood']:
    address = i +',Toronto, ON, Canada'
    geolocator = Nominatim(user_agent="vic_explorer")
    location = geolocator.geocode(address)
    latitude_list.append(location.latitude)
    longitude_list.append(location.longitude)

coordinates = pd.DataFrame({'latitude': latitude_list, 'longitude': longitude_list})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-76-d96f2520e7c9> in <module>
#       5     geolocator = Nominatim(user_agent="vic_explorer")
#       6     location = geolocator.geocode(address)
# ----> 7     latitude_list.append(location.latitude)
#       8     longitude_list.append(location.longitude)
#       9
#
# AttributeError: 'NoneType' object has no attribute 'latitude'

# %%
latitude_list = []
longitude_list = []
address = 'Wychwood' +',Toronto, ON, Canada'
geolocator = Nominatim(user_agent="vic_explorer")
location = geolocator.geocode(address)
latitude_list.append(location.latitude)
longitude_list.append(location.longitude)

coordinates = pd.DataFrame({'latitude': latitude_list, 'longitude': longitude_list})

# %%
coordinates
# Out:
#     latitude  longitude
# 0  43.682122 -79.423839
